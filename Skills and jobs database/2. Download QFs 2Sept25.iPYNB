# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import requests
import fitz
import re
from tqdm import tqdm
import os
import numpy as np

# %% [markdown]
# # Importing dataset

# %%
# CSV with scraped data
df_scraped = pd.read_csv('Active QF list with links2Sept25.csv', usecols=[1,2,3,4])
df_scraped = df_scraped[~df_scraped.isna().any(axis = 1)]
df_scraped = df_scraped.reset_index(drop = True)
display(df_scraped.head())
print(df_scraped.shape)
# Out:
#                                     Job name                      NQR code  \
# 0              Line Patrolling Man (Oil Gas)          2022/HYC/HSSCI/06782
# 1  Process Instrument Technician (Oil & Gas)  QG-04-HC-01019-2023-V2-HSSCI
# 2                         Excavator-Pipeline          2022/HYC/HSSCI/06781
# 3         Fire Safety Technician (Oil & Gas)           2020/HYC/HSSCI/3611
# 4                               Hindi Typist         2020/OAFM/MEPSC/03792
#
#                                      Job description  \
# 0  The primary role of Line Patrolling Man (Oil &...
# 1  The individual in this position is responsible...
# 2  The individual in this job is responsible for ...
# 3  The main responsibility of the fire safety tec...
# 4  The Hindi Typist, is responsible for formattin...
#
#                                              Qf link
# 0  https://www.nqr.gov.in/qualification/file/STT-...
# 1  https://www.nqr.gov.in/qualification/file/STT-...
# 2  https://www.nqr.gov.in/qualification/file/STT-...
# 3  https://www.nqr.gov.in/qualification/file/STT-...
# 4  https://www.nqr.gov.in/qualification/file/QFil...
# (2225, 4)

# %%
# Excel from NQR website
df_website = pd.read_excel(r'NQR website QF list 2Sept25.xlsx', header = 2)
df_website.head()
# Out:
#    S No.                                      Title                   Code  \
# 0      1             Line Patrolling Man (Oil  Gas)    2020/HYC/HSSCI/3770
# 1      2  Process Instrument Technician (Oil & Gas)    2020/HYC/HSSCI/3769
# 2      3                         Excavator-Pipeline    2020/HYC/HSSCI/3612
# 3      4         Fire Safety Technician (Oil & Gas)    2020/HYC/HSSCI/3611
# 4      5                               Hindi Typist  2020/OAFM/MEPSC/03792
#
#                                          Description  Sector Name    Level  \
# 0  The primary role of Line Patrolling Man (Oil &...  Hydrocarbon  Level 3
# 1  The individual in this position is responsible...  Hydrocarbon  Level 4
# 2  The individual in this job is responsible for ...  Hydrocarbon  Level 2
# 3  The main responsibility of the fire safety tec...  Hydrocarbon  Level 4
# 4  The Hindi Typist, is responsible for formattin...   Management  Level 4
#
#   Maximum Notational Hours Minimum Notational Hours   Version  \
# 0                330 Hours                330 Hours  Version
# 1                480 Hours                480 Hours  Version
# 2                240 Hours                240 Hours  Version
# 3                450 Hours                450 Hours  Version
# 4                450 Hours                390 Hours  Version
#
#   Originally Approved   Valid Till  \
# 0         17 Nov 2022  16 Nov 2025
# 1         29 Sep 2023  28 Sep 2026
# 2         17 Nov 2022  16 Nov 2025
# 3         17 Nov 2022  16 Nov 2025
# 4         17 Nov 2022  17 Nov 2025
#
#                                        Awarding Body  \
# 0           Hydrocarbon Sector Skill Council (HSSCI)
# 1           Hydrocarbon Sector Skill Council (HSSCI)
# 2           Hydrocarbon Sector Skill Council (HSSCI)
# 3           Hydrocarbon Sector Skill Council (HSSCI)
# 4  Management & Entrepreneurship and Professional...
#
#                                    Certifying Bodies  \
# 0                   Hydrocarbon Sector Skill Council
# 1                   Hydrocarbon Sector Skill Council
# 2                   Hydrocarbon Sector Skill Council
# 3                   Hydrocarbon Sector Skill Council
# 4  Management Entrepreneurship and Professional S...
#
#                                  Proposed Occupation  \
# 0                               Pipeline Maintenance
# 1  Operations - Oil & Gas Pipeline, Calibration a...
# 2                      Operations-Oil & Gas pipeline
# 3  Management of Health, Safety and Environment (...
# 4                                     Office Support
#
#                                  Progression Pathway      Qualifcation Type  \
# 0                         Senior Line Patrolling Man  General Qualification
# 1  Vertical Progression - Level 4.5: Senior Proce...  General Qualification
# 2                        Helper-Hydrocarbon Pipeline  General Qualification
# 3                      Senior Fire Safety Technician  General Qualification
# 4                  Multi-functional Office Executive  General Qualification
#
#   Adopted Qualifcation                            Training Delivery Hours
# 0                 N.A.  {"Theory":"90","Practical":"150","Employabilit...
# 1                 N.A.  {"Theory":"105","Practical":"285","Employabili...
# 2                 N.A.  {"Theory":"60","Practical":"120","Employabilit...
# 3                 N.A.  {"Theory":"120","Practical":"240","Employabili...
# 4                 N.A.  {"Theory":"150","Practical":"180","Employabili...

# %% [markdown]
# # Updating excel sheet

# %%
# Merging links with website excel

## Dropping sno 557 (index 556) because it has duplicate NQR code with another row
df_website = df_website.drop(labels = 556, axis = 0)

## Merging
df_merged = pd.merge(df_website,df_scraped[['NQR code', 'Qf link']],
                     left_on= 'Code',
                     right_on= 'NQR code',
                     validate="1:1",
                     how = 'inner')

# %%
# Cleaning merged file
df_merged = df_merged.drop('S No.', axis = 1)
df_merged['pdf_number'] = df_merged.index

# %% [markdown]
# # Reading pdfs

# %%
# Loop through each row in df and download the pdf
base_path = './v1_Downloaded active QF pdfs/'
for i in tqdm(range(0,df_merged.shape[0])):
    try:
        # Extract URL from dataframe
        file_path = base_path + str(i) + ".pdf"
        url = df_merged.loc[i,'Qf link']

        # Make GET request on the url
        response = requests.get(url)

        # Store content if request successful
        if response.status_code == 200:
            df_merged.loc[i,'working_qflink'] = 'yes'
            with open(file_path, 'wb') as file:
                file.write(response.content)
        else:
            print(f"File with index {i} not downloaded")
            df_merged.loc[i,'working_qflink'] = 'no'
    
    # Log any exception
    except Exception as e:
        print(f"Error at index {i}:\n{e}")
        df_merged.loc[i,'working_qflink'] = 'no'
# Out:
#   8%|▊         | 168/2094 [00:52<05:36,  5.73it/s]
# File with index 167 not downloaded
#  18%|█▊        | 387/2094 [01:45<06:32,  4.35it/s]
# File with index 386 not downloaded
# File with index 387 not downloaded
#  19%|█▉        | 397/2094 [01:48<08:15,  3.42it/s]
# File with index 396 not downloaded
#  19%|█▉        | 398/2094 [01:48<08:13,  3.44it/s]
# File with index 398 not downloaded
#  20%|█▉        | 411/2094 [01:51<04:53,  5.73it/s]
# File with index 409 not downloaded
# File with index 410 not downloaded
#  26%|██▌       | 538/2094 [03:23<2:52:21,  6.65s/it]
# File with index 537 not downloaded
#  31%|███       | 642/2094 [05:28<2:39:17,  6.58s/it]
# File with index 641 not downloaded
#  91%|█████████▏| 1916/2094 [13:01<19:35,  6.60s/it]
# File with index 1915 not downloaded
# 100%|██████████| 2094/2094 [14:34<00:00,  2.39it/s]

# %%
# Filtering for merged df with working QF links
df_merged = df_merged[df_merged['working_qflink'] == 'yes']

# Marking rows with pdf size of less than 100 bytes
for i in df_merged.index:
    pdf_number = df_merged.loc[i,'pdf_number']
    pdf_name = str(pdf_number) + '.pdf'
    pdf_location = "v1_Downloaded active QF pdfs/" + pdf_name
    if os.stat(pdf_location).st_size<100:
        df_merged.loc[i,'valid_pdf'] = 'no'
        os.remove(pdf_location)                                 # Deletes pdf from folder if it has a size of less than 10 byts 
    else:
        df_merged.loc[i,'valid_pdf'] = 'yes'

# Filtering for QFs with valid pdfs
df_merged = df_merged[df_merged['valid_pdf'] == 'yes']

# %%
# Deleting new columns
df_merged = df_merged.drop(columns=['working_qflink', 'valid_pdf'])

# %%
df_merged
# Out:
#                                                   Title  \
# 0                    Fire Safety Technician (Oil & Gas)
# 1                                          Hindi Typist
# 2                   Certificate Course in Coding Skills
# 3               Transit and Self-Loading Mixer Operator
# 4                                   AI – Data Architect
# ...                                                 ...
# 2089       Mechanical Automation & Maintenance Engineer
# 2090  Central Sterile Service Department (CSSD) Assi...
# 2091               Healthcare Quality Assurance Manager
# 2092                   Full Stack Development Associate
# 2093                  Purchase Executive - Construction
#
#                                Code  \
# 0               2020/HYC/HSSCI/3611
# 1             2020/OAFM/MEPSC/03792
# 2              2020/ITES/ASAP/03802
# 3                2020/CON/IESC/3881
# 4             2020/ITES/ITSSC/04327
# ...                             ...
# 2089    QG-06-IT-04198-2025-V1-CGSC
# 2090   QG-4.5-HE-04220-2025-V2-HSSC
# 2091    QG-06-HE-04225-2025-V2-HSSC
# 2092  QG-04-IT-04172-2025-V2-NIELIT
# 2093   QG-3.5-CO-04294-2025-V1-ICES
#
#                                             Description  \
# 0     The main responsibility of the fire safety tec...
# 1     The Hindi Typist, is responsible for formattin...
# 2     Individuals at this job are responsible for de...
# 3     Transit and Self-Loading Mixer operator drives...
# 4     Individuals at this job must be responsible fo...
# ...                                                 ...
# 2089  A Mechanical Automation & Maintenance Engineer...
# 2090  The individual at this job are responsible for...
# 2091  The individual’s main job is to ensure that he...
# 2092  Nature: \nThe programme encompasses people’s s...
# 2093  A Purchase Executive – Construction Material i...
#
#                         Sector Name      Level Maximum Notational Hours  \
# 0                       Hydrocarbon    Level 4                450 Hours
# 1                        Management    Level 4                450 Hours
# 2                           IT-ITeS    Level 5                270 Hours
# 3                    Infrastructure    Level 4                390 Hours
# 4                           IT-ITeS    Level 7                750 Hours
# ...                             ...        ...                      ...
# 2089  Capital Goods & Manufacturing    Level 6                660 Hours
# 2090                     Healthcare  Level 4.5               1200 Hours
# 2091                     Healthcare    Level 6                570 Hours
# 2092                        IT-ITeS    Level 4                390 Hours
# 2093                   Construction  Level 3.5                450 Hours
#
#      Minimum Notational Hours   Version Originally Approved   Valid Till  \
# 0                   450 Hours  Version          17 Nov 2022  16 Nov 2025
# 1                   390 Hours  Version          17 Nov 2022  17 Nov 2025
# 2                   270 Hours  Version          25 Jun 2020  01 Mar 2026
# 3                   390 Hours  Version          17 Oct 2019  17 Oct 2022
# 4                   660 Hours  Version          19 Dec 2018  22 Sep 2025
# ...                       ...       ...                 ...          ...
# 2089                660 Hours  Version          08 May 2025  08 May 2028
# 2090               1200 Hours  Version          08 May 2025  08 May 2028
# 2091                570 Hours  Version          08 May 2025  08 May 2028
# 2092                390 Hours  Version          08 May 2025  08 May 2028
# 2093                450 Hours  Version          08 May 2025  08 May 2028
#
#                                           Awarding Body  \
# 0              Hydrocarbon Sector Skill Council (HSSCI)
# 1     Management & Entrepreneurship and Professional...
# 2     Additional Skill Acquisition Programme, Govern...
# 3         Infrastructure Equipment Sector Skill Council
# 4     IT-ITeS Sector Skills Council NASSCOM (SSC NAS...
# ...                                                 ...
# 2089  Capital Goods and Strategic Skill Council (CGSSC)
# 2090             Healthcare Sector Skill Council (HSSC)
# 2091             Healthcare Sector Skill Council (HSSC)
# 2092  National Institute of Electronics and Informat...
# 2093           The Institute of Civil Engineers Society
#
#                                       Certifying Bodies  \
# 0                      Hydrocarbon Sector Skill Council
# 1     Management Entrepreneurship and Professional S...
# 2     Additional Skill Acquisition Programme, Govern...
# 3               Infrastructure Equipment Sector Council
# 4                                   IT-ITeS SSC NASSCOM
# ...                                                 ...
# 2089         Capital Goods and Strategic Skills Council
# 2090                    Healthcare sector skill council
# 2091                    Healthcare sector skill council
# 2092  National Institute of Electronics and Informat...
# 2093         The Institution of Civil Engineers Society
#
#                                     Proposed Occupation  \
# 0     Management of Health, Safety and Environment (...
# 1                                        Office Support
# 2                   Software Engineer /Project Engineer
# 3               Transit and Self-Loading Mixer Operator
# 4        Artificial Intelligence and Big Data Analytics
# ...                                                 ...
# 2089                                        Maintenance
# 2090                                    Non-Direct Care
# 2091                      Healthcare Quality Management
# 2092                                    Web Development
# 2093            Procuring goods, materials and services
#
#                                     Progression Pathway  \
# 0                         Senior Fire Safety Technician
# 1                     Multi-functional Office Executive
# 2     VERTICAL PROGRESSION \nEngineer Trainee, Proje...
# 3        Senior Transit and Self-Loading mixer operator
# 4     Solutions Architect, Senior Database Administr...
# ...                                                 ...
# 2089  Mechanical Automation & Maintenance Manager-Le...
# 2090           NSQF Level 5: Patient Relation Associate
# 2091  Vertical Mobility:\nNSQF Level 4: General Duty...
# 2092                               Full Stack Developer
# 2093                    Purchase Officer (NSQF Level 4)
#
#                                       Qualifcation Type Adopted Qualifcation  \
# 0                                 General Qualification                 N.A.
# 1                                 General Qualification                 N.A.
# 2     Future Skills Qualification,General Qualification                 N.A.
# 3                                 General Qualification                 N.A.
# 4                              Upskilling Qualification                 N.A.
# ...                                                 ...                  ...
# 2089  Future Skills Qualification,General Qualification                 N.A.
# 2090  Apprenticeship Qualification,General Qualifica...                 N.A.
# 2091  Apprenticeship Qualification,General Qualifica...                 N.A.
# 2092                              General Qualification                 N.A.
# 2093                              General Qualification                 N.A.
#
#                                 Training Delivery Hours  \
# 0     {"Theory":"120","Practical":"240","Employabili...
# 1     {"Theory":"150","Practical":"180","Employabili...
# 2     {"Theory":"36","Practical":"204","Employabilit...
# 3     {"Theory":"90","Practical":"150","Employabilit...
# 4     {"Theory":"180","Practical":"330","Employabili...
# ...                                                 ...
# 2089  {"Theory":"140","Practical":"310","Employabili...
# 2090  {"Theory":"330","Practical":"660","Employabili...
# 2091  {"Theory":"240","Practical":"150","Employabili...
# 2092  {"Theory":"120","Practical":"180","Employabili...
# 2093  {"Theory":"110","Practical":"220","Employabili...
#
#                            NQR code  \
# 0               2020/HYC/HSSCI/3611
# 1             2020/OAFM/MEPSC/03792
# 2              2020/ITES/ASAP/03802
# 3                2020/CON/IESC/3881
# 4             2020/ITES/ITSSC/04327
# ...                             ...
# 2089    QG-06-IT-04198-2025-V1-CGSC
# 2090   QG-4.5-HE-04220-2025-V2-HSSC
# 2091    QG-06-HE-04225-2025-V2-HSSC
# 2092  QG-04-IT-04172-2025-V2-NIELIT
# 2093   QG-3.5-CO-04294-2025-V1-ICES
#
#                                                 Qf link  pdf_number
# 0     https://www.nqr.gov.in/qualification/file/STT-...           0
# 1     https://www.nqr.gov.in/qualification/file/QFil...           1
# 2     https://www.nqr.gov.in/qualification/file/Q%20...           2
# 3     https://nqr.gov.in/sites/default/files/QF%20-I...           3
# 4     https://www.nqr.gov.in/qualification/file/SSC%...           4
# ...                                                 ...         ...
# 2089  https://www.nqr.gov.in/qualification/file/QF-M...        2089
# 2090  https://www.nqr.gov.in/qualification/file/Qual...        2090
# 2091  https://www.nqr.gov.in/qualification/file/Qual...        2091
# 2092  https://www.nqr.gov.in/qualification/file/QF_F...        2092
# 2093  https://www.nqr.gov.in/qualification/file/QF-%...        2093
#
# [2081 rows x 20 columns]

# %% [markdown]
# # Exporting

# %%
df_merged.to_csv('Final qf list_cleaned 2Sept25.csv')
