# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import numpy as np
import os
from dotenv import load_dotenv, find_dotenv
from google import genai
from google.genai import types
import google.genai.errors 
import itertools
import json
import time
from pathlib import Path
from pydantic import BaseModel
from typing import Tuple, Optional
import re
import inspect
from google.genai.types import HttpOptions

# %%
inspect.ismodule(google.genai.errors.APIError.status)
# Out:
# False

# %%
# Loading dot env file
load_dotenv(find_dotenv())
# Out:
# True

# %%
# Displaying all columns of df
pd.set_option("display.max_columns", None)

# %% [markdown]
# # Importing data

# %%
file_path = r"Uncleaned Jobs and skills database 15Sept25.parquet"
df = pd.read_parquet(file_path)
df.head()
# Out:
#                                      Title                   Code  \
# 0       Fire Safety Technician (Oil & Gas)    2020/HYC/HSSCI/3611
# 1                             Hindi Typist  2020/OAFM/MEPSC/03792
# 2      Certificate Course in Coding Skills   2020/ITES/ASAP/03802
# 3  Transit and Self-Loading Mixer Operator     2020/CON/IESC/3881
# 4                      AI – Data Architect  2020/ITES/ITSSC/04327
#
#                                          Description     Sector Name    Level  \
# 0  The main responsibility of the fire safety tec...     Hydrocarbon  Level 4
# 1  The Hindi Typist, is responsible for formattin...      Management  Level 4
# 2  Individuals at this job are responsible for de...         IT-ITeS  Level 5
# 3  Transit and Self-Loading Mixer operator drives...  Infrastructure  Level 4
# 4  Individuals at this job must be responsible fo...         IT-ITeS  Level 7
#
#   Maximum Notational Hours Minimum Notational Hours   Version  \
# 0                450 Hours                450 Hours  Version
# 1                450 Hours                390 Hours  Version
# 2                270 Hours                270 Hours  Version
# 3                390 Hours                390 Hours  Version
# 4                750 Hours                660 Hours  Version
#
#   Originally Approved   Valid Till  \
# 0         17 Nov 2022  16 Nov 2025
# 1         17 Nov 2022  17 Nov 2025
# 2         25 Jun 2020  01 Mar 2026
# 3         17 Oct 2019  17 Oct 2022
# 4         19 Dec 2018  22 Sep 2025
#
#                                        Awarding Body  \
# 0           Hydrocarbon Sector Skill Council (HSSCI)
# 1  Management & Entrepreneurship and Professional...
# 2  Additional Skill Acquisition Programme, Govern...
# 3      Infrastructure Equipment Sector Skill Council
# 4  IT-ITeS Sector Skills Council NASSCOM (SSC NAS...
#
#                                    Certifying Bodies  \
# 0                   Hydrocarbon Sector Skill Council
# 1  Management Entrepreneurship and Professional S...
# 2  Additional Skill Acquisition Programme, Govern...
# 3            Infrastructure Equipment Sector Council
# 4                                IT-ITeS SSC NASSCOM
#
#                                  Proposed Occupation  \
# 0  Management of Health, Safety and Environment (...
# 1                                     Office Support
# 2                Software Engineer /Project Engineer
# 3            Transit and Self-Loading Mixer Operator
# 4     Artificial Intelligence and Big Data Analytics
#
#                                  Progression Pathway  \
# 0                      Senior Fire Safety Technician
# 1                  Multi-functional Office Executive
# 2  VERTICAL PROGRESSION \nEngineer Trainee, Proje...
# 3     Senior Transit and Self-Loading mixer operator
# 4  Solutions Architect, Senior Database Administr...
#
#                                    Qualifcation Type Adopted Qualifcation  \
# 0                              General Qualification                 N.A.
# 1                              General Qualification                 N.A.
# 2  Future Skills Qualification,General Qualification                 N.A.
# 3                              General Qualification                 N.A.
# 4                           Upskilling Qualification                 N.A.
#
#                              Training Delivery Hours               NQR code  \
# 0  {"Theory":"120","Practical":"240","Employabili...    2020/HYC/HSSCI/3611
# 1  {"Theory":"150","Practical":"180","Employabili...  2020/OAFM/MEPSC/03792
# 2  {"Theory":"36","Practical":"204","Employabilit...   2020/ITES/ASAP/03802
# 3  {"Theory":"90","Practical":"150","Employabilit...     2020/CON/IESC/3881
# 4  {"Theory":"180","Practical":"330","Employabili...  2020/ITES/ITSSC/04327
#
#                                              Qf link  pdf_number  \
# 0  https://www.nqr.gov.in/qualification/file/STT-...           0
# 1  https://www.nqr.gov.in/qualification/file/QFil...           1
# 2  https://www.nqr.gov.in/qualification/file/Q%20...           2
# 3  https://nqr.gov.in/sites/default/files/QF%20-I...           3
# 4  https://www.nqr.gov.in/qualification/file/SSC%...           4
#
#   nco_code_full nco_4digit_code  \
# 0   [3119.0800]          [3119]
# 1   [4131.9900]          [4131]
# 2   [2512.0800]          [2512]
# 3   [8114.0300]          [8114]
# 4          None            None
#
#                                              pc_text
# 0  [maintain fire safety equipment as per mainten...
# 1  [access specified data or information using sp...
# 2                                               None
# 3  [support in administering basic firstaid and r...
# 4  [encourage team members with diverse view poin...

# %%
# Loading API keys
api_keys = [os.getenv("gemini_api_tm_per"), os.getenv("gemini_api_tm_ceew") ]

# %%
# Loading txt file with indices of unprocessed rows
with open ("gemma_unprocessed_rows.txt") as f:
    file = f.read()
    file = file.split("\n")
    file = list(map(int,file))
    gemini_unprocessed_rows = file
print(f"{len(gemini_unprocessed_rows)} unprocessed files from GEMINI loaded here")
# Out:
# 172 unprocessed files from GEMINI loaded here

# %% [markdown]
# # Data wrangling

# %%
# Indexing each pc task in each job
df.at[:,'indexed_pc'] = df['pc_text'].map(lambda pc: [(x[0],str(y)) for x,y in np.ndenumerate(pc)] if pc is not None else None)

# %% [markdown]
# # Processing

# %%
# Creating batches
def batch_skill (skill_list, batch_size = 20):
    l = len(skill_list)
    for idx in range (0,l,batch_size):
        yield skill_list[idx:min(idx+batch_size,l)]

# %%
# Setting up Groq
api_cycle = itertools.cycle(api_keys)
timeout_secs = 6*1000
client = genai.Client(api_key=next(api_cycle), http_options= HttpOptions(timeout=timeout_secs))

# %%
# Function to change client if rate limit is hit
def change_client ():
    global client
    client = genai.Client(api_key = next(api_cycle), http_options= HttpOptions(timeout=timeout_secs))
    print("Changed to another API key")

# %%
# Create unprocessed rows.txt if not there
file_name = 'groq_unprocessed_rows.txt'
if not Path(file_name).exists(): 
    with open (file_name, 'w') as f:
        print ("Empty txt file for storing index of unprocessed rows created.")
        pass
else:
    print(f"File {file_name} already exists")

# Create processed rows.txt if not there
file_name = 'groq_processed_rows.txt'
if not Path(file_name).exists(): 
    with open (file_name, 'w') as f:
        print ("Empty txt file for storing index of processed rows created.")
        pass
else:
    print(f"File {file_name} already exists")
# Out:
# Empty txt file for storing index of unprocessed rows created.
# Empty txt file for storing index of processed rows created.

# %%
# Initialising stop
stop = False

# %%
# Processing a single job
def clean_single_job (row_index: int, batch_size = 20,table = df, max_attempts = 5, model_name = 'gemini-2.5-flash-lite'):
    
    # Stop flag 
    global stop

    # Defining metadata
    job_name = table.loc[row_index, 'Title']
    job_description = table.loc[row_index, 'Description']
    sector_name = table.loc[row_index, 'Sector Name']
    skill_list = table.loc[row_index, 'indexed_pc']

    # Initialising job level clean skills list
    clean_skills_job = []
    
    # Creating batches
    skill_batches = [x for x in batch_skill(skill_list = skill_list, batch_size=batch_size)]

    # Processing batches
    for i,batch in enumerate(skill_batches):
        
        print(f"processing batch {i+1} of {len(skill_batches)}")
        # Defining system prompt
        system_prompt = """
                            You are a JSON generator. Respond ONLY with valid JSON. 
                            - Output ONLY the raw JSON with no markdown formatting, no code blocks, no ```json markers, and no additional text.
                            - Do NOT provide any explanation or extra text.

                            For each item, return [unique_id, flag, original_description, corrected_description]:
                            - If skill description is complete: [unique_id, 0, "original_description", null]
                            - If skill description is incomplete: [unique_id, 1, "original_description", "corrected description"]

                            Rules:
                            - Input will be a list of tuples: (unique_id, skill description).
                            - Use null (not None) for empty values.
                            - Use unique_id as provided.
                            - Use double quotes for all strings.
                            - No explanations, no extra text.
                            - Length of output must equal length of input list.
                            - Ensure valid JSON syntax.

                            Output format:
                            {
                            "results": [
                                [unique_id, 0, "some description", null],
                                [unique_id, 1, "incomplete desc", "fixed version"]
                                        ]
                            }

                            Incorrect format (do not do this):
                            ```json
                            {
                            "results": [
                                [unique_id, 0, "some description", null],
                                [unique_id, 1, "incomplete desc", "fixed version"]
                                        ]
                            }```
                            """
        # Defining user prompt
        user_prompt = f"""
                Skills to analyze: {batch}
                Job details: 
                    job name: {job_name}
                    job description: {job_description} 
                    sector name: {sector_name}
                Return corrected versions of the skill descriptions in the instructed format.   
                """
        
        # Don't process the batch if daily api limit is hit, i.e., stop = True
        if stop:
            break

        # Make LLM call
        current_attempt = 1
        while current_attempt <=max_attempts:
            
            # Initialising batch list
            clean_skills_batch = None

            # Chat completion
            try:
                chat_completion = client.models.generate_content(
                                    contents= system_prompt + user_prompt,
                                    model = model_name,
                                )
                
                if chat_completion.text:
                            # Remove markdown elements put by gemini SDK
                            results = re.sub(r'^```json\s*|\s*```$', '', chat_completion.text, flags=re.MULTILINE)
                            results = json.loads(results)

            # APIError
            except google.genai.errors.APIError as e:
                if e.code == 503:
                    print(f"Api error 503 occurred. Trying after 20 seconds. Error: {e}")
                    current_attempt +=1
                    time.sleep(20)
                    print(f"Attempt number: {current_attempt} for batch {i+1} of job {row_index}")
                    current_attempt+=1
                    continue
                elif e.code == 429:
                    print(f"API error 429 occured. Daily limit exhausted. Changing API key. Error: {e}")
                    current_attempt +=1
                    time.sleep(2)
                    print(f"Attempt number: {current_attempt} for batch {i+1} of job {row_index}")
                    change_client()
                    continue

            
            # All other exceptions
            except Exception as e:
                print(f"Unexpected exception occurred: {e}")
                current_attempt +=1
                print(f"Attempt number: {current_attempt} for batch {i+1} of job {row_index}")
                time.sleep(2)
                continue

            if results:
                # If LLM returns a dictionary
                if isinstance(results, dict) and "results" in results:
                    if (len(results["results"]) == len(batch)):                         # Checks if returned size is same as batch size
                        if all(isinstance(x,list) for x in results["results"]):          # Checks if a list is returned
                            if all(x is not None for x in results["results"]):          # Checks if No skill is returned as None
                                if all(len(x) == 4 for x in results["results"]):        # Checks if each array is of size 4
                                    clean_skills_batch = results["results"]
                                    clean_skills_job.extend(clean_skills_batch)
                                    break
                            else:
                                print(f"None value returned for some skill in batch {i+1} fpr job {row_index}. Trying again")
                                current_attempt+=1
                        else:
                            print(f"Some skill not returned as a valid list in batch {i+1} for job {row_index}. Trying again")
                            current_attempt+=1
                    else:
                        print(f"Skills length {len(results['results'])} not equal to {len(batch)}, trying again.")
                        current_attempt+=1
                
                # If llm returns a list of list
                elif isinstance(results, list):
                    if len(results) == len(batch):                                  # Checks if returned size is same as batch size 
                        if all(isinstance(x,list) for x in results):                # Checks if a list is returned
                            if all(x is not None for x in results):                 # Checks if No skill is returned as None
                                if all(len(x) == 4 for x in results):               # Checks if each array is of size 4
                                    clean_skills_batch = results
                                    clean_skills_job.extend(clean_skills_batch)
                                    break
                            else:
                                print(f"None value returned for some skill in batch {i+1} fpr job {row_index}. Trying again")
                                current_attempt+=1
                        else:
                            print(f"Some skill not returned as a valid list in batch {i+1} for job {row_index}. Trying again")
                            current_attempt+=1
                    else:
                        print(f"Skills length {len(results)} not equal to {len(batch)}, trying again.")
                        current_attempt+=1

                
        if clean_skills_batch is None:
            print(f"Processing for batch {i+1} in job {row_index} failed. Not processing this job")
            return None
        
    # Final return
    if clean_skills_job:
        return clean_skills_job
    else:
        print(f"Processing for job with index {row_index} failed.")
        return None

# %%
# Processing data

## Initialising empty list of unprocessed rows
unprocessed_rows = []
processed_rows = []


## Rows to process
batch_df = df.loc[df.index.isin(gemini_unprocessed_rows)].sort_index(ascending=True).copy()
batch_df['processed_pc'] = None

# Processing for each row in batch df

stop = False
for index, row in batch_df.iterrows():
    
    # Initializing stop flag for API Rate Limit
    print("*"*20,f"Processing row {index}","*"*20)
    
    # Processing rows with pc text
    if row['indexed_pc']:
        clean_pc = clean_single_job(index)
        if clean_pc:
            batch_df.at[index, 'processed_pc'] = clean_pc.to_list if isinstance(clean_pc,np.ndarray) else clean_pc
            processed_rows.append(index)
        else:
            if stop == False:
                batch_df.at[index, 'processed_pc'] = None
                unprocessed_rows.append(index)
            elif stop == True:
                print(f"Api limit over for the day, could not process row: {index}", "*"*20)
                break                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
    
    # Processing rows without pc text
    else:
        batch_df.loc[index, 'processed_pc'] = None
        processed_rows.append(index)

print(f"Rows processed with index: {processed_rows}")
# Out:
# ******************** Processing row 119 ********************
# processing batch 1 of 4
# processing batch 2 of 4
# processing batch 3 of 4
# processing batch 4 of 4
# ******************** Processing row 120 ********************
# processing batch 1 of 4
# processing batch 2 of 4
# processing batch 3 of 4
# processing batch 4 of 4
# ******************** Processing row 216 ********************
# processing batch 1 of 6
# processing batch 2 of 6
# processing batch 3 of 6
# processing batch 4 of 6
# processing batch 5 of 6
# processing batch 6 of 6
# ******************** Processing row 303 ********************
# processing batch 1 of 3
# processing batch 2 of 3
# processing batch 3 of 3
# API error 429 occured. Daily limit exhausted. Changing API key. Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15\nPlease retry in 45.91473157s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '45s'}]}}
# Attempt number: 2 for batch 3 of job 303
# Changed to another API key
# ******************** Processing row 305 ********************
# processing batch 1 of 3
# processing batch 2 of 3
# processing batch 3 of 3
# ******************** Processing row 446 ********************
# processing batch 1 of 9
# processing batch 2 of 9
# processing batch 3 of 9
# processing batch 4 of 9
# processing batch 5 of 9
# processing batch 6 of 9
# processing batch 7 of 9
# processing batch 8 of 9
# processing batch 9 of 9
# ******************** Processing row 476 ********************
# processing batch 1 of 5
# processing batch 2 of 5
# processing batch 3 of 5
# processing batch 4 of 5
# API error 429 occured. Daily limit exhausted. Changing API key. Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15\nPlease retry in 12.349738817s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash-lite', 'location': 'global'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '12s'}]}}
# Attempt number: 2 for batch 4 of job 476
# Changed to another API key
# processing batch 5 of 5
# ******************** Processing row 492 ********************
# processing batch 1 of 4
# processing batch 2 of 4
# Unexpected exception occurred: Expecting ',' delimiter: line 1 column 2202 (char 2201)
# Attempt number: 2 for batch 2 of job 492
# processing batch 3 of 4
# processing batch 4 of 4
# ******************** Processing row 496 ********************
# processing batch 1 of 4
# processing batch 2 of 4
# processing batch 3 of 4
# processing batch 4 of 4
# ******************** Processing row 504 ********************
# processing batch 1 of 3
# processing batch 2 of 3
# processing batch 3 of 3
# ******************** Processing row 506 ********************
# processing batch 1 of 9
# processing batch 2 of 9
# processing batch 3 of 9
# processing batch 4 of 9
# API error 429 occured. Daily limit exhausted. Changing API key. Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15\nPlease retry in 34.592836631s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '34s'}]}}
# Attempt number: 2 for batch 4 of job 506
# Changed to another API key
# processing batch 5 of 9
# processing batch 6 of 9
# processing batch 7 of 9
# processing batch 8 of 9
# processing batch 9 of 9
# ******************** Processing row 509 ********************
# processing batch 1 of 15
# processing batch 2 of 15
# processing batch 3 of 15
# processing batch 4 of 15
# processing batch 5 of 15
# processing batch 6 of 15
# processing batch 7 of 15
# processing batch 8 of 15
# processing batch 9 of 15
# processing batch 10 of 15
# API error 429 occured. Daily limit exhausted. Changing API key. Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15\nPlease retry in 57.261722565s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash-lite', 'location': 'global'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '57s'}]}}
# Attempt number: 2 for batch 10 of job 509
# Changed to another API key
# processing batch 11 of 15
# processing batch 12 of 15
# processing batch 13 of 15
# processing batch 14 of 15
# processing batch 15 of 15
# ******************** Processing row 517 ********************
# processing batch 1 of 6
# processing batch 2 of 6
# processing batch 3 of 6
# processing batch 4 of 6
# processing batch 5 of 6
# processing batch 6 of 6
# ******************** Processing row 521 ********************
# processing batch 1 of 30
# processing batch 2 of 30
# processing batch 3 of 30
# processing batch 4 of 30
# processing batch 5 of 30
# API error 429 occured. Daily limit exhausted. Changing API key. Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15\nPlease retry in 22.690789488s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '22s'}]}}
# Attempt number: 2 for batch 5 of job 521
# Changed to another API key
# processing batch 6 of 30
# processing batch 7 of 30
# processing batch 8 of 30
# processing batch 9 of 30
# processing batch 10 of 30
# processing batch 11 of 30
# processing batch 12 of 30
# processing batch 13 of 30
# processing batch 14 of 30
# processing batch 15 of 30
# processing batch 16 of 30
# processing batch 17 of 30
# processing batch 18 of 30
# processing batch 19 of 30
# processing batch 20 of 30
# API error 429 occured. Daily limit exhausted. Changing API key. Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15\nPlease retry in 51.995189616s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '51s'}]}}
# Attempt number: 2 for batch 20 of job 521
# Changed to another API key
# processing batch 21 of 30
# processing batch 22 of 30
# processing batch 23 of 30
# processing batch 24 of 30
# processing batch 25 of 30
# processing batch 26 of 30
# processing batch 27 of 30
# processing batch 28 of 30
# processing batch 29 of 30
# processing batch 30 of 30
# ******************** Processing row 538 ********************
# processing batch 1 of 10
# processing batch 2 of 10
# processing batch 3 of 10
# processing batch 4 of 10
# processing batch 5 of 10
# API error 429 occured. Daily limit exhausted. Changing API key. Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15\nPlease retry in 20.601947638s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '20s'}]}}
# Attempt number: 2 for batch 5 of job 538
# Changed to another API key
# processing batch 6 of 10
# processing batch 7 of 10
# processing batch 8 of 10
# processing batch 9 of 10
# processing batch 10 of 10
# ******************** Processing row 554 ********************
# processing batch 1 of 10
# processing batch 2 of 10
# processing batch 3 of 10
# processing batch 4 of 10
# processing batch 5 of 10
# processing batch 6 of 10
# processing batch 7 of 10
# processing batch 8 of 10
# processing batch 9 of 10
# processing batch 10 of 10
# ******************** Processing row 560 ********************
# processing batch 1 of 8
# API error 429 occured. Daily limit exhausted. Changing API key. Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15\nPlease retry in 47.244745791s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '47s'}]}}
# Attempt number: 2 for batch 1 of job 560
# Changed to another API key
# processing batch 2 of 8
# processing batch 3 of 8
# processing batch 4 of 8
# processing batch 5 of 8
# processing batch 6 of 8
# processing batch 7 of 8
# processing batch 8 of 8
# ******************** Processing row 564 ********************
# processing batch 1 of 11
# processing batch 2 of 11
# processing batch 3 of 11
# processing batch 4 of 11
# processing batch 5 of 11
# processing batch 6 of 11
# processing batch 7 of 11
# processing batch 8 of 11
# processing batch 9 of 11
# processing batch 10 of 11
# processing batch 11 of 11
# ******************** Processing row 567 ********************
# processing batch 1 of 6
# processing batch 2 of 6
# processing batch 3 of 6
# processing batch 4 of 6
# processing batch 5 of 6
# processing batch 6 of 6
# ******************** Processing row 572 ********************
# processing batch 1 of 11
# processing batch 2 of 11
# processing batch 3 of 11
# processing batch 4 of 11
# processing batch 5 of 11
# processing batch 6 of 11
# processing batch 7 of 11
# API error 429 occured. Daily limit exhausted. Changing API key. Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15\nPlease retry in 44.29890008s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '44s'}]}}
# Attempt number: 2 for batch 7 of job 572
# Changed to another API key
# processing batch 8 of 11
# processing batch 9 of 11
# processing batch 10 of 11
# processing batch 11 of 11
# ******************** Processing row 575 ********************
# processing batch 1 of 8
# processing batch 2 of 8
# processing batch 3 of 8
# processing batch 4 of 8
# processing batch 5 of 8
# processing batch 6 of 8
# processing batch 7 of 8
# processing batch 8 of 8
# ******************** Processing row 577 ********************
# processing batch 1 of 9
# processing batch 2 of 9
# processing batch 3 of 9
# API error 429 occured. Daily limit exhausted. Changing API key. Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15\nPlease retry in 14.951412362s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '14s'}]}}
# Attempt number: 2 for batch 3 of job 577
# Changed to another API key
# processing batch 4 of 9
# processing batch 5 of 9
# processing batch 6 of 9
# processing batch 7 of 9
# processing batch 8 of 9
# processing batch 9 of 9
# ******************** Processing row 590 ********************
# processing batch 1 of 9
# processing batch 2 of 9
# processing batch 3 of 9
# processing batch 4 of 9
# processing batch 5 of 9
# processing batch 6 of 9
# processing batch 7 of 9
# processing batch 8 of 9
# processing batch 9 of 9
# ******************** Processing row 623 ********************
# processing batch 1 of 7
# API error 429 occured. Daily limit exhausted. Changing API key. Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15\nPlease retry in 41.15821915s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '41s'}]}}
# Attempt number: 2 for batch 1 of job 623
# Changed to another API key
# processing batch 2 of 7
# processing batch 3 of 7
# processing batch 4 of 7
# processing batch 5 of 7
# processing batch 6 of 7
# processing batch 7 of 7
# ******************** Processing row 644 ********************
# processing batch 1 of 17
# processing batch 2 of 17
# processing batch 3 of 17
# processing batch 4 of 17
# processing batch 5 of 17
# processing batch 6 of 17
# processing batch 7 of 17
# processing batch 8 of 17
# processing batch 9 of 17
# processing batch 10 of 17
# API error 429 occured. Daily limit exhausted. Changing API key. Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15\nPlease retry in 6.703178533s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '6s'}]}}
# Attempt number: 2 for batch 10 of job 644
# Changed to another API key
# processing batch 11 of 17
# processing batch 12 of 17
# processing batch 13 of 17
# processing batch 14 of 17
# processing batch 15 of 17
# processing batch 16 of 17
# processing batch 17 of 17
# ******************** Processing row 698 ********************
# processing batch 1 of 1
# ******************** Processing row 753 ********************
# processing batch 1 of 8
# processing batch 2 of 8
# processing batch 3 of 8
# processing batch 4 of 8
# processing batch 5 of 8
# processing batch 6 of 8
# processing batch 7 of 8
# API error 429 occured. Daily limit exhausted. Changing API key. Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15\nPlease retry in 33.318407254s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '33s'}]}}
# Attempt number: 2 for batch 7 of job 753
# Changed to another API key
# processing batch 8 of 8
# Unexpected exception occurred: Extra data: line 1 column 599 (char 598)
# Attempt number: 2 for batch 8 of job 753
# ******************** Processing row 762 ********************
# processing batch 1 of 1
# ******************** Processing row 767 ********************
# processing batch 1 of 2
# processing batch 2 of 2
# ******************** Processing row 768 ********************
# processing batch 1 of 1
# ******************** Processing row 769 ********************
# processing batch 1 of 2
# processing batch 2 of 2
# ******************** Processing row 771 ********************
# processing batch 1 of 6
# Unexpected exception occurred: Expecting value: line 1 column 1816 (char 1815)
# Attempt number: 2 for batch 1 of job 771
# Unexpected exception occurred: Expecting value: line 1 column 1951 (char 1950)
# Attempt number: 3 for batch 1 of job 771
# processing batch 2 of 6
# processing batch 3 of 6
# processing batch 4 of 6
# processing batch 5 of 6
# processing batch 6 of 6
# Unexpected exception occurred: Extra data: line 1 column 1508 (char 1507)
# Attempt number: 2 for batch 6 of job 771
# API error 429 occured. Daily limit exhausted. Changing API key. Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15\nPlease retry in 45.684678455s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash-lite', 'location': 'global'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '45s'}]}}
# Attempt number: 3 for batch 6 of job 771
# Changed to another API key
# ******************** Processing row 773 ********************
# processing batch 1 of 2
# processing batch 2 of 2
# ******************** Processing row 774 ********************
# processing batch 1 of 2
# processing batch 2 of 2
# Skills length 14 not equal to 13, trying again.
# ******************** Processing row 806 ********************
# processing batch 1 of 5
# processing batch 2 of 5
# processing batch 3 of 5
# processing batch 4 of 5
# processing batch 5 of 5
# ******************** Processing row 901 ********************
# processing batch 1 of 3
# processing batch 2 of 3
# processing batch 3 of 3
# ******************** Processing row 913 ********************
# processing batch 1 of 5
# processing batch 2 of 5
# processing batch 3 of 5
# processing batch 4 of 5
# processing batch 5 of 5
# Unexpected exception occurred: Expecting ',' delimiter: line 1 column 5471 (char 5470)
# Attempt number: 2 for batch 5 of job 913
# ******************** Processing row 938 ********************
# processing batch 1 of 3
# Unexpected exception occurred: Expecting ',' delimiter: line 1 column 5240 (char 5239)
# Attempt number: 2 for batch 1 of job 938
# processing batch 2 of 3
# processing batch 3 of 3
# ******************** Processing row 947 ********************
# processing batch 1 of 7
# processing batch 2 of 7
# processing batch 3 of 7
# processing batch 4 of 7
# API error 429 occured. Daily limit exhausted. Changing API key. Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15\nPlease retry in 32.487343272s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash-lite', 'location': 'global'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '32s'}]}}
# Attempt number: 2 for batch 4 of job 947
# Changed to another API key
# processing batch 5 of 7
# processing batch 6 of 7
# processing batch 7 of 7
# ******************** Processing row 956 ********************
# processing batch 1 of 7
# processing batch 2 of 7
# processing batch 3 of 7
# Skills length 24 not equal to 20, trying again.
# processing batch 4 of 7
# processing batch 5 of 7
# processing batch 6 of 7
# processing batch 7 of 7
# ******************** Processing row 959 ********************
# processing batch 1 of 7
# processing batch 2 of 7
# processing batch 3 of 7
# processing batch 4 of 7
# processing batch 5 of 7
# API error 429 occured. Daily limit exhausted. Changing API key. Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15\nPlease retry in 51.837359188s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '51s'}]}}
# Attempt number: 2 for batch 5 of job 959
# Changed to another API key
# processing batch 6 of 7
# processing batch 7 of 7
# ******************** Processing row 971 ********************
# processing batch 1 of 17
# processing batch 2 of 17
# processing batch 3 of 17
# processing batch 4 of 17
# processing batch 5 of 17
# processing batch 6 of 17
# processing batch 7 of 17
# processing batch 8 of 17
# processing batch 9 of 17
# processing batch 10 of 17
# processing batch 11 of 17
# processing batch 12 of 17
# processing batch 13 of 17
# processing batch 14 of 17
# API error 429 occured. Daily limit exhausted. Changing API key. Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15\nPlease retry in 20.07060033s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '20s'}]}}
# Attempt number: 2 for batch 14 of job 971
# Changed to another API key
# processing batch 15 of 17
# processing batch 16 of 17
# processing batch 17 of 17
# ******************** Processing row 976 ********************
# processing batch 1 of 5
# processing batch 2 of 5
# processing batch 3 of 5
# processing batch 4 of 5
# processing batch 5 of 5
# ******************** Processing row 981 ********************
# processing batch 1 of 10
# processing batch 2 of 10
# processing batch 3 of 10
# processing batch 4 of 10
# processing batch 5 of 10
# processing batch 6 of 10
# processing batch 7 of 10
# processing batch 8 of 10
# API error 429 occured. Daily limit exhausted. Changing API key. Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15\nPlease retry in 45.611851212s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '45s'}]}}
# Attempt number: 2 for batch 8 of job 981
# Changed to another API key
# processing batch 9 of 10
# processing batch 10 of 10
# ******************** Processing row 984 ********************
# processing batch 1 of 11
# processing batch 2 of 11
# processing batch 3 of 11
# processing batch 4 of 11
# processing batch 5 of 11
# processing batch 6 of 11
# processing batch 7 of 11
# processing batch 8 of 11
# processing batch 9 of 11
# processing batch 10 of 11
# processing batch 11 of 11
# ******************** Processing row 991 ********************
# processing batch 1 of 4
# processing batch 2 of 4
# processing batch 3 of 4
# processing batch 4 of 4
# ******************** Processing row 993 ********************
# processing batch 1 of 11
# processing batch 2 of 11
# processing batch 3 of 11
# processing batch 4 of 11
# processing batch 5 of 11
# processing batch 6 of 11
# processing batch 7 of 11
# processing batch 8 of 11
# processing batch 9 of 11
# processing batch 10 of 11
# API error 429 occured. Daily limit exhausted. Changing API key. Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15\nPlease retry in 45.802405823s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash-lite', 'location': 'global'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '45s'}]}}
# Attempt number: 2 for batch 10 of job 993
# Changed to another API key
# processing batch 11 of 11
# ******************** Processing row 1006 ********************
# processing batch 1 of 11
# processing batch 2 of 11
# processing batch 3 of 11
# processing batch 4 of 11
# processing batch 5 of 11
# processing batch 6 of 11
# processing batch 7 of 11
# processing batch 8 of 11
# processing batch 9 of 11
# processing batch 10 of 11
# processing batch 11 of 11
# ******************** Processing row 1016 ********************
# processing batch 1 of 6
# processing batch 2 of 6
# processing batch 3 of 6
# processing batch 4 of 6
# processing batch 5 of 6
# API error 429 occured. Daily limit exhausted. Changing API key. Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15\nPlease retry in 4.655986558s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '4s'}]}}
# Attempt number: 2 for batch 5 of job 1016
# Changed to another API key
# processing batch 6 of 6
# ******************** Processing row 1034 ********************
# processing batch 1 of 6
# processing batch 2 of 6
# processing batch 3 of 6
# processing batch 4 of 6
# processing batch 5 of 6
# processing batch 6 of 6
# ******************** Processing row 1042 ********************
# processing batch 1 of 6
# processing batch 2 of 6
# processing batch 3 of 6
# processing batch 4 of 6
# processing batch 5 of 6
# processing batch 6 of 6
# ******************** Processing row 1045 ********************
# processing batch 1 of 5
# processing batch 2 of 5
# processing batch 3 of 5
# processing batch 4 of 5
# API error 429 occured. Daily limit exhausted. Changing API key. Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15\nPlease retry in 25.812934214s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '25s'}]}}
# Attempt number: 2 for batch 4 of job 1045
# Changed to another API key
# processing batch 5 of 5
# ******************** Processing row 1057 ********************
# processing batch 1 of 5
# processing batch 2 of 5
# processing batch 3 of 5
# processing batch 4 of 5
# processing batch 5 of 5
# ******************** Processing row 1058 ********************
# processing batch 1 of 4
# processing batch 2 of 4
# processing batch 3 of 4
# processing batch 4 of 4
# ******************** Processing row 1071 ********************
# processing batch 1 of 6
# processing batch 2 of 6
# processing batch 3 of 6
# processing batch 4 of 6
# processing batch 5 of 6
# processing batch 6 of 6
# API error 429 occured. Daily limit exhausted. Changing API key. Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15\nPlease retry in 50.249789422s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '50s'}]}}
# Attempt number: 2 for batch 6 of job 1071
# Changed to another API key
# ******************** Processing row 1127 ********************
# processing batch 1 of 11
# processing batch 2 of 11
# processing batch 3 of 11
# processing batch 4 of 11
# processing batch 5 of 11
# processing batch 6 of 11
# processing batch 7 of 11
# processing batch 8 of 11
# processing batch 9 of 11
# processing batch 10 of 11
# processing batch 11 of 11
# ******************** Processing row 1128 ********************
# processing batch 1 of 6
# processing batch 2 of 6
# processing batch 3 of 6
# processing batch 4 of 6
# processing batch 5 of 6
# processing batch 6 of 6
# ******************** Processing row 1129 ********************
# processing batch 1 of 6
# processing batch 2 of 6
# processing batch 3 of 6
# processing batch 4 of 6
# processing batch 5 of 6
# processing batch 6 of 6
# ******************** Processing row 1136 ********************
# processing batch 1 of 12
# Unexpected exception occurred: Extra data: line 1 column 2660 (char 2659)
# Attempt number: 2 for batch 1 of job 1136
# processing batch 2 of 12
# processing batch 3 of 12
# processing batch 4 of 12
# processing batch 5 of 12
# processing batch 6 of 12
# API error 429 occured. Daily limit exhausted. Changing API key. Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15\nPlease retry in 38.117577886s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '38s'}]}}
# Attempt number: 2 for batch 6 of job 1136
# Changed to another API key
# processing batch 7 of 12
# processing batch 8 of 12
# processing batch 9 of 12
# processing batch 10 of 12
# processing batch 11 of 12
# processing batch 12 of 12
# ******************** Processing row 1138 ********************
# processing batch 1 of 8
# processing batch 2 of 8
# processing batch 3 of 8
# processing batch 4 of 8
# processing batch 5 of 8
# processing batch 6 of 8
# processing batch 7 of 8
# processing batch 8 of 8
# ******************** Processing row 1160 ********************
# processing batch 1 of 8
# processing batch 2 of 8
# API error 429 occured. Daily limit exhausted. Changing API key. Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15\nPlease retry in 1.465508812s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '1s'}]}}
# Attempt number: 2 for batch 2 of job 1160
# Changed to another API key
# processing batch 3 of 8
# processing batch 4 of 8
# processing batch 5 of 8
# processing batch 6 of 8
# processing batch 7 of 8
# processing batch 8 of 8
# ******************** Processing row 1163 ********************
# processing batch 1 of 8
# processing batch 2 of 8
# processing batch 3 of 8
# processing batch 4 of 8
# processing batch 5 of 8
# processing batch 6 of 8
# processing batch 7 of 8
# processing batch 8 of 8
# ******************** Processing row 1170 ********************
# processing batch 1 of 5
# processing batch 2 of 5
# API error 429 occured. Daily limit exhausted. Changing API key. Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15\nPlease retry in 28.819899923s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '28s'}]}}
# Attempt number: 2 for batch 2 of job 1170
# Changed to another API key
# processing batch 3 of 5
# processing batch 4 of 5
# processing batch 5 of 5
# ******************** Processing row 1171 ********************
# processing batch 1 of 7
# processing batch 2 of 7
# processing batch 3 of 7
# processing batch 4 of 7
# processing batch 5 of 7
# processing batch 6 of 7
# processing batch 7 of 7
# ******************** Processing row 1172 ********************
# processing batch 1 of 7
# processing batch 2 of 7
# processing batch 3 of 7
# processing batch 4 of 7
# processing batch 5 of 7
# API error 429 occured. Daily limit exhausted. Changing API key. Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15\nPlease retry in 54.966799742s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash-lite', 'location': 'global'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '54s'}]}}
# Attempt number: 2 for batch 5 of job 1172
# Changed to another API key
# processing batch 6 of 7
# processing batch 7 of 7
# Unexpected exception occurred: Extra data: line 1 column 1456 (char 1455)
# Attempt number: 2 for batch 7 of job 1172
# ******************** Processing row 1176 ********************
# processing batch 1 of 9
# processing batch 2 of 9
# processing batch 3 of 9
# processing batch 4 of 9
# processing batch 5 of 9
# processing batch 6 of 9
# processing batch 7 of 9
# processing batch 8 of 9
# processing batch 9 of 9
# ******************** Processing row 1180 ********************
# processing batch 1 of 11
# processing batch 2 of 11
# Unexpected exception occurred: Expecting ',' delimiter: line 1 column 2950 (char 2949)
# Attempt number: 2 for batch 2 of job 1180
# processing batch 3 of 11
# processing batch 4 of 11
# processing batch 5 of 11
# processing batch 6 of 11
# processing batch 7 of 11
# processing batch 8 of 11
# processing batch 9 of 11
# processing batch 10 of 11
# processing batch 11 of 11
# ******************** Processing row 1181 ********************
# processing batch 1 of 9
# processing batch 2 of 9
# processing batch 3 of 9
# processing batch 4 of 9
# processing batch 5 of 9
# processing batch 6 of 9
# processing batch 7 of 9
# ...
# Attempt number: 2 for batch 2 of job 1862
# Changed to another API key
# processing batch 3 of 9
# processing batch 4 of 9
# processing batch 5 of 9
# processing batch 6 of 9
# processing batch 7 of 9
# processing batch 8 of 9
# processing batch 9 of 9
# ******************** Processing row 1889 ********************
# processing batch 1 of 10
# processing batch 2 of 10
# processing batch 3 of 10
# processing batch 4 of 10
# processing batch 5 of 10
# processing batch 6 of 10
# processing batch 7 of 10
# processing batch 8 of 10
# API error 429 occured. Daily limit exhausted. Changing API key. Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15\nPlease retry in 36.651291442s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash-lite', 'location': 'global'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '36s'}]}}
# Attempt number: 2 for batch 8 of job 1889
# Changed to another API key
# processing batch 9 of 10
# processing batch 10 of 10
# ******************** Processing row 1896 ********************
# processing batch 1 of 3
# processing batch 2 of 3
# processing batch 3 of 3
# ******************** Processing row 1897 ********************
# processing batch 1 of 2
# processing batch 2 of 2
# ******************** Processing row 1901 ********************
# processing batch 1 of 1
# ******************** Processing row 1903 ********************
# processing batch 1 of 4
# processing batch 2 of 4
# processing batch 3 of 4
# processing batch 4 of 4
# ******************** Processing row 1924 ********************
# processing batch 1 of 4
# processing batch 2 of 4
# processing batch 3 of 4
# processing batch 4 of 4
# API error 429 occured. Daily limit exhausted. Changing API key. Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15\nPlease retry in 5.855288756s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '5s'}]}}
# Attempt number: 2 for batch 4 of job 1924
# Changed to another API key
# ******************** Processing row 1928 ********************
# processing batch 1 of 9
# processing batch 2 of 9
# processing batch 3 of 9
# processing batch 4 of 9
# processing batch 5 of 9
# processing batch 6 of 9
# processing batch 7 of 9
# processing batch 8 of 9
# processing batch 9 of 9
# ******************** Processing row 1929 ********************
# processing batch 1 of 5
# processing batch 2 of 5
# processing batch 3 of 5
# processing batch 4 of 5
# processing batch 5 of 5
# ******************** Processing row 1936 ********************
# processing batch 1 of 8
# API error 429 occured. Daily limit exhausted. Changing API key. Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15\nPlease retry in 35.295268849s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '35s'}]}}
# Attempt number: 2 for batch 1 of job 1936
# Changed to another API key
# processing batch 2 of 8
# processing batch 3 of 8
# processing batch 4 of 8
# processing batch 5 of 8
# processing batch 6 of 8
# processing batch 7 of 8
# processing batch 8 of 8
# ******************** Processing row 1938 ********************
# processing batch 1 of 1
# ******************** Processing row 1939 ********************
# processing batch 1 of 7
# processing batch 2 of 7
# processing batch 3 of 7
# processing batch 4 of 7
# processing batch 5 of 7
# processing batch 6 of 7
# processing batch 7 of 7
# ******************** Processing row 1940 ********************
# processing batch 1 of 6
# API error 429 occured. Daily limit exhausted. Changing API key. Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15\nPlease retry in 58.402793315s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '58s'}]}}
# Attempt number: 2 for batch 1 of job 1940
# Changed to another API key
# processing batch 2 of 6
# processing batch 3 of 6
# processing batch 4 of 6
# processing batch 5 of 6
# processing batch 6 of 6
# ******************** Processing row 1941 ********************
# processing batch 1 of 8
# processing batch 2 of 8
# processing batch 3 of 8
# processing batch 4 of 8
# processing batch 5 of 8
# processing batch 6 of 8
# processing batch 7 of 8
# processing batch 8 of 8
# ******************** Processing row 1945 ********************
# processing batch 1 of 7
# processing batch 2 of 7
# API error 429 occured. Daily limit exhausted. Changing API key. Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15\nPlease retry in 26.437047665s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '26s'}]}}
# Attempt number: 2 for batch 2 of job 1945
# Changed to another API key
# processing batch 3 of 7
# processing batch 4 of 7
# processing batch 5 of 7
# processing batch 6 of 7
# processing batch 7 of 7
# ******************** Processing row 1976 ********************
# processing batch 1 of 9
# processing batch 2 of 9
# processing batch 3 of 9
# processing batch 4 of 9
# processing batch 5 of 9
# processing batch 6 of 9
# processing batch 7 of 9
# processing batch 8 of 9
# processing batch 9 of 9
# ******************** Processing row 1984 ********************
# processing batch 1 of 5
# processing batch 2 of 5
# API error 429 occured. Daily limit exhausted. Changing API key. Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15\nPlease retry in 56.068975703s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash-lite', 'location': 'global'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '56s'}]}}
# Attempt number: 2 for batch 2 of job 1984
# Changed to another API key
# processing batch 3 of 5
# processing batch 4 of 5
# processing batch 5 of 5
# ******************** Processing row 1987 ********************
# processing batch 1 of 7
# processing batch 2 of 7
# processing batch 3 of 7
# processing batch 4 of 7
# processing batch 5 of 7
# processing batch 6 of 7
# processing batch 7 of 7
# ******************** Processing row 1999 ********************
# processing batch 1 of 6
# processing batch 2 of 6
# processing batch 3 of 6
# processing batch 4 of 6
# processing batch 5 of 6
# processing batch 6 of 6
# API error 429 occured. Daily limit exhausted. Changing API key. Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15\nPlease retry in 22.965471634s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '22s'}]}}
# Attempt number: 2 for batch 6 of job 1999
# Changed to another API key
# ******************** Processing row 2037 ********************
# processing batch 1 of 10
# processing batch 2 of 10
# processing batch 3 of 10
# processing batch 4 of 10
# processing batch 5 of 10
# processing batch 6 of 10
# processing batch 7 of 10
# processing batch 8 of 10
# processing batch 9 of 10
# processing batch 10 of 10
# ******************** Processing row 2040 ********************
# processing batch 1 of 6
# processing batch 2 of 6
# processing batch 3 of 6
# processing batch 4 of 6
# processing batch 5 of 6
# processing batch 6 of 6
# ******************** Processing row 2066 ********************
# processing batch 1 of 8
# API error 429 occured. Daily limit exhausted. Changing API key. Error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15\nPlease retry in 48.586222765s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '48s'}]}}
# Attempt number: 2 for batch 1 of job 2066
# Changed to another API key
# processing batch 2 of 8
# processing batch 3 of 8
# processing batch 4 of 8
# processing batch 5 of 8
# processing batch 6 of 8
# processing batch 7 of 8
# processing batch 8 of 8
# ******************** Processing row 2068 ********************
# processing batch 1 of 7
# processing batch 2 of 7
# processing batch 3 of 7
# processing batch 4 of 7
# processing batch 5 of 7
# processing batch 6 of 7
# processing batch 7 of 7
# ******************** Processing row 2071 ********************
# processing batch 1 of 5
# processing batch 2 of 5
# processing batch 3 of 5
# processing batch 4 of 5
# processing batch 5 of 5
# Rows processed with index: [119, 120, 216, 303, 305, 446, 476, 492, 496, 504, 506, 509, 517, 521, 538, 554, 560, 564, 567, 572, 575, 577, 590, 623, 644, 698, 753, 762, 767, 768, 769, 771, 773, 774, 806, 901, 913, 938, 947, 956, 959, 971, 976, 981, 984, 991, 993, 1006, 1016, 1034, 1042, 1045, 1057, 1058, 1071, 1127, 1128, 1129, 1136, 1138, 1160, 1163, 1170, 1171, 1172, 1176, 1180, 1181, 1182, 1211, 1224, 1225, 1231, 1252, 1253, 1257, 1265, 1281, 1282, 1284, 1288, 1290, 1291, 1292, 1293, 1332, 1346, 1353, 1354, 1358, 1359, 1364, 1365, 1386, 1390, 1401, 1408, 1414, 1418, 1426, 1427, 1435, 1436, 1437, 1445, 1451, 1463, 1465, 1471, 1472, 1473, 1488, 1503, 1505, 1507, 1512, 1516, 1517, 1518, 1545, 1555, 1561, 1579, 1587, 1612, 1614, 1636, 1652, 1658, 1665, 1671, 1694, 1704, 1717, 1720, 1725, 1730, 1732, 1733, 1734, 1741, 1746, 1770, 1781, 1783, 1811, 1827, 1861, 1862, 1889, 1896, 1897, 1901, 1903, 1924, 1928, 1929, 1936, 1938, 1939, 1940, 1941, 1945, 1976, 1984, 1987, 1999, 2037, 2040, 2066, 2068, 2071]

# %%
# Saving batch
def save_batch (batch_id, table,folder = "llm_batches"):    
    
    # Make directory if it doesnt exist
    os.makedirs(folder, exist_ok=True)

    # Saving data frame
    file_name = f"{folder}/batch_{batch_id}.parquet"
    if not Path(file_name).exists():                                                                    
        for col in ['pc_text', 'indexed_pc', 'processed_pc']:
            table = table.copy()
            table [col] = table [col].apply(lambda x: json.dumps(x.tolist() if isinstance(x, np.ndarray) else x) 
                                                if isinstance(x, (list, np.ndarray)) else x)
        table.to_parquet(file_name, index=True)
    else:
        print("Chosen batch id already exists")

# %%
# Storing batch file
save_batch('residual_batches', batch_df)
