# %% [markdown]
# # Importing libraries

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.chrome.options import Options
import pyperclip
import ast
import pandas as pd

# %% [markdown]
# # Setting up

# %%
# List of IDs for qualification files
with open ("PDF_suffix_webscraped.txt", 'r') as f:
    content = f.read()
qf_list = content.strip().split(",")
print(f"Length of qf list: {len(qf_list)}")
# Out:
# Length of qf list: 2227

# %%
# URL to be appended to PDF suffixes
base_url = "https://www.nqr.gov.in/qualifications/"

# %%
# Intializing empty dictionary to collect scraped data
data_dict = {"Job name": [],
       "NQR code": [],
       "Job description": [],
       "Qf link": []}

# %%
# Extracting data (in batches)
batch = qf_list[2000:]
for i, id in enumerate(batch):


    # Status
    print(f"Fetching {i+1}/{len(batch)} file with id {id}")

    
    # Fetch url
    url = base_url + str(id)
    try:
        options = Options()
        options.add_argument("--headless=new")
        driver = webdriver.Chrome(options = options)
        driver.get(url)
        #print("Link opened successfully")
    
        # Extract relavant portions
        ## Job name
        try:
            # Wait for element to be located
            wait = WebDriverWait(driver, 10)
            def page_loaded (driver):
                element = driver.find_element(By.XPATH, "/html/body/div/div[3]/div[2]/div/div/h1")
                return element.text.strip() != ""
            wait.until(page_loaded)
            #print("page fully loaded successfully")
        except Exception as e:
                print ("Exception occured")

        try:
            element = driver.find_element(By.XPATH, "/html/body/div/div[3]/div[2]/div/div/h1")
            data_dict['Job name'].append(element.text)
        except Exception as e:
            print(f"Failed to fetch job name for sno {i+1} with id {id}")
            data_dict['Job name'].append(None)
            print(e)

        ## NQR code
        try:
            element = driver.find_element(By.XPATH, "/html/body/div[1]/div[3]/div[2]/div/div/div/span")
            data_dict['NQR code'].append(element.text)
        except Exception as e:
            print(f"Failed to fetch job nqr code for sno {i+1} with id {id}")
            data_dict['NQR code'].append(None)
            print(e)
        
        ## Job description
        try:
            element = driver.find_element(By.XPATH, "/html/body/div[1]/section/div/div[1]/div/div[2]/div[2]/p")
            data_dict['Job description'].append(element.text)
        except Exception as e:
            print(e)
            print(f"Failed to fetch job description for sno {i+1} with id {id}")
            data_dict['Job description'].append(None)

        ## QF link
        try:
            element = driver.find_element(By.XPATH, "/html/body/div[1]/section/div/div[2]/aside/div[4]/ul[1]/li")
            data_dict['Qf link'].append(element.find_element(By.TAG_NAME, "a").get_attribute("href"))
        except Exception as e:
            print(e)
            print(f"Failed to fetch qf link for sno {i+1} with id {id}")
            data_dict['Qf link'].append(None)
    
    
    except Exception as e:
        print(e)
        continue

    finally:
        driver.quit()
# Out:
# Fetching 1/227 file with id 13499
# Fetching 2/227 file with id 13503
# Fetching 3/227 file with id 13508
# Fetching 4/227 file with id 13510
# Fetching 5/227 file with id 13511
# Fetching 6/227 file with id 13512
# Fetching 7/227 file with id 13514
# Fetching 8/227 file with id 13517
# Fetching 9/227 file with id 13518
# Fetching 10/227 file with id 13519
# Fetching 11/227 file with id 13525
# Fetching 12/227 file with id 13526
# Fetching 13/227 file with id 13527
# Fetching 14/227 file with id 13529
# Fetching 15/227 file with id 13531
# Fetching 16/227 file with id 13532
# Fetching 17/227 file with id 13534
# Fetching 18/227 file with id 13536
# Fetching 19/227 file with id 13538
# Fetching 20/227 file with id 13540
# Fetching 21/227 file with id 13543
# Fetching 22/227 file with id 13545
# Fetching 23/227 file with id 13547
# Fetching 24/227 file with id 13548
# Fetching 25/227 file with id 13550
# Fetching 26/227 file with id 13556
# Fetching 27/227 file with id 13563
# Fetching 28/227 file with id 13564
# Fetching 29/227 file with id 13568
# Fetching 30/227 file with id 13570
# Fetching 31/227 file with id 13573
# Fetching 32/227 file with id 13578
# Fetching 33/227 file with id 13583
# Fetching 34/227 file with id 13585
# Fetching 35/227 file with id 13592
# Fetching 36/227 file with id 13593
# Fetching 37/227 file with id 13596
# Fetching 38/227 file with id 13600
# Fetching 39/227 file with id 13607
# Fetching 40/227 file with id 13609
# Fetching 41/227 file with id 13610
# Fetching 42/227 file with id 13611
# Fetching 43/227 file with id 13612
# Fetching 44/227 file with id 13615
# Fetching 45/227 file with id 13616
# Fetching 46/227 file with id 13617
# Fetching 47/227 file with id 13618
# Fetching 48/227 file with id 13619
# Fetching 49/227 file with id 13620
# Fetching 50/227 file with id 13621
# Fetching 51/227 file with id 13622
# Fetching 52/227 file with id 13623
# Fetching 53/227 file with id 13624
# Fetching 54/227 file with id 13625
# Fetching 55/227 file with id 13626
# Fetching 56/227 file with id 13628
# Fetching 57/227 file with id 13629
# Fetching 58/227 file with id 13631
# Fetching 59/227 file with id 13634
# Fetching 60/227 file with id 13635
# Fetching 61/227 file with id 13637
# Fetching 62/227 file with id 13638
# Fetching 63/227 file with id 13639
# Fetching 64/227 file with id 13640
# Fetching 65/227 file with id 13641
# Fetching 66/227 file with id 13644
# Fetching 67/227 file with id 13645
# Fetching 68/227 file with id 13646
# Fetching 69/227 file with id 13647
# Fetching 70/227 file with id 13648
# Fetching 71/227 file with id 13656
# Fetching 72/227 file with id 13660
# Fetching 73/227 file with id 13664
# Fetching 74/227 file with id 13665
# Fetching 75/227 file with id 13666
# Fetching 76/227 file with id 13667
# Fetching 77/227 file with id 13670
# Fetching 78/227 file with id 13671
# Fetching 79/227 file with id 13672
# Fetching 80/227 file with id 13674
# Fetching 81/227 file with id 13675
# Fetching 82/227 file with id 13676
# Fetching 83/227 file with id 13677
# Fetching 84/227 file with id 13682
# Fetching 85/227 file with id 13683
# Fetching 86/227 file with id 13684
# Fetching 87/227 file with id 13685
# Fetching 88/227 file with id 13689
# Fetching 89/227 file with id 13694
# Fetching 90/227 file with id 13704
# Fetching 91/227 file with id 13707
# Fetching 92/227 file with id 13709
# Fetching 93/227 file with id 13710
# Fetching 94/227 file with id 13711
# Fetching 95/227 file with id 13714
# Fetching 96/227 file with id 13718
# Fetching 97/227 file with id 13720
# Fetching 98/227 file with id 13726
# Fetching 99/227 file with id 13730
# Fetching 100/227 file with id 13731
# Fetching 101/227 file with id 13732
# Fetching 102/227 file with id 13734
# Fetching 103/227 file with id 13738
# Fetching 104/227 file with id 13743
# Fetching 105/227 file with id 13744
# Fetching 106/227 file with id 13745
# Fetching 107/227 file with id 13748
# Fetching 108/227 file with id 13750
# Fetching 109/227 file with id 13754
# Fetching 110/227 file with id 13756
# Fetching 111/227 file with id 13759
# Fetching 112/227 file with id 13760
# Fetching 113/227 file with id 13763
# Fetching 114/227 file with id 13768
# Fetching 115/227 file with id 13770
# Fetching 116/227 file with id 13772
# Fetching 117/227 file with id 13774
# Fetching 118/227 file with id 13783
# Fetching 119/227 file with id 13786
# Fetching 120/227 file with id 13794
# Fetching 121/227 file with id 13801
# Fetching 122/227 file with id 13811
# Fetching 123/227 file with id 13812
# Fetching 124/227 file with id 13816
# Fetching 125/227 file with id 13820
# Fetching 126/227 file with id 13827
# Fetching 127/227 file with id 13837
# Fetching 128/227 file with id 13839
# Fetching 129/227 file with id 13844
# Fetching 130/227 file with id 13850
# Fetching 131/227 file with id 13851
# Fetching 132/227 file with id 13853
# Fetching 133/227 file with id 13856
# Fetching 134/227 file with id 13859
# Fetching 135/227 file with id 13861
# Fetching 136/227 file with id 13863
# Fetching 137/227 file with id 13876
# Fetching 138/227 file with id 13878
# Fetching 139/227 file with id 13882
# Fetching 140/227 file with id 13906
# Fetching 141/227 file with id 13908
# Fetching 142/227 file with id 13909
# Fetching 143/227 file with id 13911
# Fetching 144/227 file with id 13916
# Fetching 145/227 file with id 13919
# Fetching 146/227 file with id 13924
# Fetching 147/227 file with id 13941
# Fetching 148/227 file with id 13950
# Fetching 149/227 file with id 13953
# Fetching 150/227 file with id 13954
# Fetching 151/227 file with id 13965
# Fetching 152/227 file with id 13969
# Fetching 153/227 file with id 13982
# Fetching 154/227 file with id 13986
# Fetching 155/227 file with id 13988
# Fetching 156/227 file with id 13995
# Fetching 157/227 file with id 13998
# Fetching 158/227 file with id 13999
# Fetching 159/227 file with id 14003
# Fetching 160/227 file with id 14005
# Fetching 161/227 file with id 14006
# Fetching 162/227 file with id 14007
# Fetching 163/227 file with id 14009
# Fetching 164/227 file with id 14014
# Fetching 165/227 file with id 14017
# Fetching 166/227 file with id 14018
# Fetching 167/227 file with id 14019
# Fetching 168/227 file with id 14020
# Fetching 169/227 file with id 14031
# Fetching 170/227 file with id 14036
# Fetching 171/227 file with id 14037
# Fetching 172/227 file with id 14038
# Fetching 173/227 file with id 14039
# Fetching 174/227 file with id 14040
# Fetching 175/227 file with id 14044
# Fetching 176/227 file with id 14054
# Fetching 177/227 file with id 14055
# Fetching 178/227 file with id 14058
# Fetching 179/227 file with id 14059
# Fetching 180/227 file with id 14061
# Fetching 181/227 file with id 14063
# Fetching 182/227 file with id 14068
# Fetching 183/227 file with id 14073
# Fetching 184/227 file with id 14076
# Fetching 185/227 file with id 14079
# Fetching 186/227 file with id 14082
# Fetching 187/227 file with id 14083
# Fetching 188/227 file with id 14091
# Fetching 189/227 file with id 14093
# Fetching 190/227 file with id 14097
# Fetching 191/227 file with id 14098
# Fetching 192/227 file with id 14100
# Fetching 193/227 file with id 14103
# Fetching 194/227 file with id 14107
# Fetching 195/227 file with id 14109
# Fetching 196/227 file with id 14115
# Fetching 197/227 file with id 14123
# Fetching 198/227 file with id 14125
# Fetching 199/227 file with id 14127
# Fetching 200/227 file with id 14138
# Fetching 201/227 file with id 14157
# Fetching 202/227 file with id 14158
# Fetching 203/227 file with id 14165
# Fetching 204/227 file with id 14167
# Fetching 205/227 file with id 14171
# Fetching 206/227 file with id 14173
# Fetching 207/227 file with id 14174
# Fetching 208/227 file with id 14175
# Fetching 209/227 file with id 14194
# Fetching 210/227 file with id 14211
# Fetching 211/227 file with id 14216
# Fetching 212/227 file with id 14217
# Fetching 213/227 file with id 14218
# Fetching 214/227 file with id 14225
# Fetching 215/227 file with id 14227
# Fetching 216/227 file with id 14229
# Fetching 217/227 file with id 14231
# Fetching 218/227 file with id 14234
# Fetching 219/227 file with id 14235
# Fetching 220/227 file with id 14237
# Fetching 221/227 file with id 14241
# Fetching 222/227 file with id 14242
# Fetching 223/227 file with id 14246
# Fetching 224/227 file with id 14248
# Fetching 225/227 file with id 14249
# Fetching 226/227 file with id 14250
# Fetching 227/227 file with id 14265

# %%
# Converting dictionary into dataframe
df = pd.DataFrame(data_dict)
df

# %% [markdown]
# # Exporting dataframe

# %%
df.to_csv("Active QF list with links 2Sept25.csv")
